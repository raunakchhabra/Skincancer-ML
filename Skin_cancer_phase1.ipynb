# %%
import numpy as np
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("54339-104884-bundle-archive/HAM10000_metadata.csv")

# %%
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
df.tail()
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back

# %%
df.shape
# Out:
# (10015, 7)

# %%
df['localization'].nunique()
# Out:
# 15

# %%
df['localization'].unique()
# Out:
# array(['scalp', 'ear', 'face', 'back', 'trunk', 'chest',
#        'upper extremity', 'abdomen', 'unknown', 'lower extremity',
#        'genital', 'neck', 'hand', 'foot', 'acral'], dtype=object)

# %%
df['sex'].nunique()
# Out:
# 3

# %%
df['sex'].unique()
# Out:
# array(['male', 'female', 'unknown'], dtype=object)

# %%
df['age'].nunique()
# Out:
# 18

# %%
df['age'].unique()
# Out:
# array([80., 75., 60., 70., 55., 85., 65., 40., 50., 45., 35.,  0., 30.,
#        nan,  5., 25., 20., 10., 15.])

# %%
df['lesion_id'].nunique()
# Out:
# 7470

# %%
df['lesion_id'].unique()
# Out:
# array(['HAM_0000118', 'HAM_0002730', 'HAM_0001466', ..., 'HAM_0005579',
#        'HAM_0001576', 'HAM_0002867'], dtype=object)

# %%
df['dx'].nunique()
# Out:
# 7

# %%
df['dx'].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
dk = pd.read_csv("54339-104884-bundle-archive/hmnist_8_8_RGB.csv")

# %%
dk.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        199        156        188        210        165        198
# 1        115         87        115        180        133        158
# 2        203        146        164        209        144        153
# 3        135         96        110        198        141        156
# 4        204        156        187        232        185        216
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0183  pixel0184  \
# 0        216        176        203        215  ...        214        167
# 1        200        153        187        215  ...        207        167
# 2        217        160        181        215  ...        211        160
# 3        208        148        158        210  ...        179        141
# 4        236        196        220        217  ...        236        189
#
#    pixel0185  pixel0186  pixel0187  pixel0188  pixel0189  pixel0190  \
# ...

# %%
dk.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        205        186        202        208        184        194
# 10011        103         89         88        156        133        134
# 10012        178        160        165        206        184        190
# 10013        166        124        142        179        138        156
# 10014        178        145        124        178        145        123
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0183  pixel0184  \
# 10010        211        183        188        221  ...        229        205
# 10011        183        157        159        205  ...        199        172
# 10012        228        204        210        242  ...        241        216
# 10013        186        138        156        188  ...        195        178
# 10014        177        143        118        176  ...        185        158
#
# ...

# %%
dr = pd.read_csv("54339-104884-bundle-archive/hmnist_28_28_L.csv")

# %%
dr.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        169        171        170        177        181        182
# 1         19         57        105        140        149        148
# 2        155        163        161        167        167        172
# 3         25         71        116        139        136        153
# 4        129        162        181        196        205        208
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0775  pixel0776  \
# 0        181        185        194        192  ...        184        186
# 1        144        155        170        170  ...        172        175
# 2        155        152        165        175  ...        163        178
# 3        148        161        172        162  ...        125        135
# 4        205        213        225        224  ...        210        197
#
#    pixel0777  pixel0778  pixel0779  pixel0780  pixel0781  pixel0782  \
# ...

# %%
dr.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        172        171        173        175        164        187
# 10011          2         34        108        116        114        119
# 10012        122        154        162        170        179        197
# 10013        137        143        141        139        147        152
# 10014        149        157        157        152        151        152
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0775  pixel0776  \
# 10010        207        210        208        206  ...        210        217
# 10011        131        139        139        145  ...        173        169
# 10012        200        195        202        199  ...        221        215
# 10013        155        152        155        159  ...        172        171
# 10014        154        163        149        145  ...        159        154
#
# ...

# %%
dv = pd.read_csv("54339-104884-bundle-archive/hmnist_28_28_RGB.csv")

# %%
dv.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# ...

# %%
dv.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        183        165        181        182        165        180
# 10011          2          3          1         38         33         32
# 10012        132        118        118        167        149        149
# 10013        160        124        146        164        131        152
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 10010        184        166        182        188  ...        208        185
# 10011        121        104        103        132  ...         96         79
# 10012        175        156        160        184  ...        204        181
# 10013        167        127        146        169  ...        185        162
# 10014        181        150        133        178  ...        159         79
#
# ...

# %%
df1 = pd.read_csv("54339-104884-bundle-archive/hmnist_8_8_L.csv")

# %%
df1.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        172        182        191        183        180        181
# 1         98        149        170        193        183        162
# 2        165        164        179        172        152        163
# 3        109        159        167        166        163        159
# 4        173        202        210        194        208        248
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0055  pixel0056  \
# 0        165        164        173        192  ...        159        171
# 1        164        100        137        175  ...        135         83
# 2        169        151        168        174  ...        169        152
# 3        155         96        141        168  ...        101         79
# 4        243        205        180        142  ...        230        160
#
#    pixel0057  pixel0058  pixel0059  pixel0060  pixel0061  pixel0062  \
# ...

# %%
df1.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        193        192        191        198        182        191
# 10011         93        139        165        183        188        180
# 10012        165        191        211        227        222        208
# 10013        138        152        154        161        173        177
# 10014        152        152        150        148        156        159
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0055  pixel0056  \
# 10010        213        202        199        204  ...        202        206
# 10011        150         65        147        164  ...        137        145
# 10012        210        164        193        203  ...        189        184
# 10013        179        171        144        157  ...        172        143
# 10014        158        163        153        155  ...        140        143
#
# ...

# %%
newdf= pd.merge(dk,dr, on ="pixel0000")

# %%
newdf.head()
# Out:
#    pixel0000  pixel0001_x  pixel0002_x  pixel0003_x  pixel0004_x  pixel0005_x  \
# 0        199          156          188          210          165          198
# 1        199          156          188          210          165          198
# 2        199          156          188          210          165          198
# 3        199          156          188          210          165          198
# 4        199          156          188          210          165          198
#
#    pixel0006_x  pixel0007_x  pixel0008_x  pixel0009_x  ...  pixel0775  \
# 0          216          176          203          215  ...        192
# 1          216          176          203          215  ...        190
# 2          216          176          203          215  ...        200
# 3          216          176          203          215  ...        156
# 4          216          176          203          215  ...        206
#
#    pixel0776  pixel0777  pixel0778  pixel0779  pixel0780  pixel0781  \
# ...

# %%
newdf.tail()
# Out:
#         pixel0000  pixel0001_x  pixel0002_x  pixel0003_x  pixel0004_x  \
# 491822         61           50           62          165          152
# 491823         61           50           62          165          152
# 491824         61           50           62          165          152
# 491825         61           50           62          165          152
# 491826         61           50           62          165          152
#
#         pixel0005_x  pixel0006_x  pixel0007_x  pixel0008_x  pixel0009_x  ...  \
# 491822          172          176          167          186          174  ...
# 491823          172          176          167          186          174  ...
# 491824          172          176          167          186          174  ...
# 491825          172          176          167          186          174  ...
# 491826          172          176          167          186          174  ...
#
#         pixel0775  pixel0776  pixel0777  pixel0778  pixel0779  pixel0780  \
# ...

# %%
import matplotlib as plt
import seaborn as sns

# %%
df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
df.groupby('sex').mean()
# Out:
#                age
# sex
# female   48.711522
# male     54.545370
# unknown  37.500000

# %%
from matplotlib import pyplot as plt 
import numpy as np 
  
gender = "male", "female", "unknown"
mean_age = [54.545370,48.711522,37.500000]


plt.pie(mean_age, labels = gender)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df['dx'], bins =70)
plt.show()

# %%
plt.hist(df['dx_type'], bins =70)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-5946ad7f3793> in <module>
# ----> 1 plt.scatter(df,dv)
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...
